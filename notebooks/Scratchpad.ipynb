// %% [markdown]
// ## Pseudocode
//
// 1. Parse command line args
// 1. Check command line args valid
// 1. Open file
// 1. Initialize response data structure
// 1. While (file lines remain)
//     1. Extract group from row
//     1. Search response data structure for group
//         1. IF EXISTS - increment count for group
//         1. ELSE - concat group to end of list
//     1. Next line

// %%
@file:Repository("https://repo1.maven.org/maven2")
@file:DependsOn("com.github.holgerbrandl:krangl:0.15.8")

// %%
import krangl.*
import java.io.*

// %%
var csvReader: BufferedReader = BufferedReader(FileReader("../src/main/resources/CrunchBase-Companies-2017-09-05.csv"))

// %%
val reader = BufferedReader(FileReader("../src/main/resources/CrunchBase-Companies-2017-09-05.csv"))
var line: String? = null
while ({ line = reader.readLine(); line }() != null) {
    var d = arrayOf(line?.split(","));
    System.out.println(d);
}
// Out:
// [Ljava.util.List;@59ba2555
// [Ljava.util.List;@42c9b9f5
// [Ljava.util.List;@65209097
// [Ljava.util.List;@6f29ac2
// [Ljava.util.List;@eea87c4
// [Ljava.util.List;@16381fd
// [Ljava.util.List;@60a60d6e
// [Ljava.util.List;@7210af32
// [Ljava.util.List;@281ec213
// [Ljava.util.List;@356fc284
// [Ljava.util.List;@65f2743a
// [Ljava.util.List;@12ec2e89
// [Ljava.util.List;@4c3c789d
// [Ljava.util.List;@70cf87c
// [Ljava.util.List;@71a91f03
// [Ljava.util.List;@242efd9
// [Ljava.util.List;@2d95879c
// [Ljava.util.List;@4dba554a
// [Ljava.util.List;@74d21af9
// [Ljava.util.List;@61fb1f9d
// [Ljava.util.List;@60d3cd59
// [Ljava.util.List;@7fdcd40c
// [Ljava.util.List;@1bbd0cdc
// [Ljava.util.List;@2283ffc1
// [Ljava.util.List;@5cc447cd
// [Ljava.util.List;@452194ed
// [Ljava.util.List;@3609ab79
// [Ljava.util.List;@b49378e
// [Ljava.util.List;@754df305
// [Ljava.util.List;@3c8287bd
// [Ljava.util.List;@472bb137
// [Ljava.util.List;@51c1b1b
// [Ljava.util.List;@1fd31566
// ...
